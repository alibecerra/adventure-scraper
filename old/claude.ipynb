# %%
from bs4 import BeautifulSoup
import re
import requests
import json
from tabulate import tabulate
from concurrent.futures import ThreadPoolExecutor

# URLs and API endpoints
main_page = "https://www.csusb.edu/recreation-wellness/adventure/trips/all-trips-date"
base_url = "https://www.csusb.edu"
api_url = "https://recshop.csusb.edu/Program/GetOfferingsForSemester"
querystring = {
    "semesterId": "29ff794d-548e-407f-b511-10d04ec2798e",
    "programId": "d921b108-4059-4eef-bd42-9bd9c72c2557"
}
headers = {"cookie": "ASP.NET_SessionId=b4omal1okxattmuwb1rmyqpn"}

# Fetch JS-rendered data from the API
def fetch_api_data():
    try:
        response = requests.get(api_url, headers=headers, params=querystring)
        if response.status_code == 200:
            return json.loads(response.text)
        else:
            print(f"API request failed with status code: {response.status_code}")
            return []
    except Exception as e:
        print(f"Error fetching API data: {e}")
        return []

# Get trip data from the API
api_data = fetch_api_data()

# Create lookup dictionary for spots information from API data
spots_lookup = {}
if api_data:
    for offering in api_data:
        trip_name = offering.get('Name', '')
        spots_total = offering.get('MaxRegistrants', 0)
        spots_taken = offering.get('CurrentRegistrations', 0)
        spots_left = max(0, spots_total - spots_taken)
        spots_lookup[trip_name.strip().lower()] = f"{spots_left} spot(s) left"

# Getting the adventure page to get all the current trips
response = requests.get(main_page)
soup = BeautifulSoup(response.text, 'html.parser')

list_of_href = soup.find_all('a', href=True)
pattern = re.compile(r'\/event\/\d{5,6}')

href_trips = []

for i in list_of_href:
    match = re.search(pattern, str(i))
    if match:
        href_trips.append(match.group())

def fetch_trip_info(page):
    try:
        trip = requests.get(base_url + page)
        trip_soup = BeautifulSoup(trip.text, 'html.parser')
        
        # Extract basic trip information
        trip_date = trip_soup.find('div', class_="event--date").text.strip()
        trip_name = trip_soup.find('h2', class_="event--title").text.strip()
        
        # Try to get spots left information
        fusion_button = trip_soup.find('p', class_="card-text")
        spots_left = "0 spot(s)"
        
        # First check if we have this trip in our API data
        trip_key = trip_name.lower()
        if trip_key in spots_lookup:
            spots_left = spots_lookup[trip_key]
        # If not in API data, try the traditional scraping method
        elif fusion_button is not None and hasattr(fusion_button, 'get') and fusion_button.get('href'):
            try:
                trip_spots = requests.get(fusion_button.get('href'))
                fusions_page = BeautifulSoup(trip_spots.text, 'html.parser')
                spots_left_outer = fusions_page.find('div', class_="tag-bg-grey spots-tag rounded p-1 mr-3 mb-2")
                if spots_left_outer and spots_left_outer.find('p', class_="card-text"):
                    spots_left = spots_left_outer.find('p', class_="card-text").text
            except Exception as e:
                print(f"Error fetching fusion page for {trip_name}: {e}")
        
        return [trip_name, trip_date, spots_left]
    except Exception as e:
        print(f"Error processing {page}: {e}")
        return ["Error", "Error", "Error"]

# Using ThreadPoolExecutor to fetch trip info concurrently
with ThreadPoolExecutor(max_workers=16) as executor:
    scraped_data = list(executor.map(fetch_trip_info, href_trips))

# Filter out error entries
scraped_data = [entry for entry in scraped_data if entry[0] != "Error"]

# Insert header row
scraped_data.insert(0, ["Trip Name", "Trip Date", "Spots left"])

# Print the tabulated data
table = tabulate(scraped_data, headers="firstrow", tablefmt="grid")
print(table)

# Optionally save to a file
with open("csusb_trips.txt", "w") as f:
    f.write(table)
# Out:
# Error fetching API data: Expecting value: line 3 column 5 (char 8)
# +------------------------------------------------+---------------------------------+--------------+
# | Trip Name                                      | Trip Date                       | Spots left   |
# +================================================+=================================+==============+
# | Disneyland Shuttle - SBC                       | March 2, 2025                   | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Queer Skies Ahead Hike - SBC                   | March 7, 2025                   | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Silverwood Lake Kayak - SBC                    | March 9, 2025                   | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Morro Bay Camp and Kayak - SBC                 | March 14, 2025 - March 16, 2025 | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Pinnacles National Park Camp and Explore - SBC | March 21, 2025 - March 23, 2025 | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Big Bear Service and Hike - SBC                | March 22, 2025                  | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Zion Camp and Explore Angels Landing - SBC     | March 29, 2025 - April 2, 2025  | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Black Canyon Canoe and Camp - SBC              | April 3, 2025 - April 6, 2025   | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Six Flags Magic Mountain - SBC                 | April 6, 2025                   | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Leo Carrillo Beach Camp and Explore - SBC      | April 12, 2025 - April 13, 2025 | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | La Jolla Snorkel and Hike - SBC                | April 13, 2025                  | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Yosemite Camp and Explore - SBC                | April 18, 2025 - April 20, 2025 | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Tahquitz Peak Hike - SBC                       | April 19, 2025                  | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | SAIL Program Only: Silverwood Lake Kayak - SBC | April 25, 2025                  | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Indoor Skydiving - SBC                         | April 25, 2025                  | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Kings River Whitewater Raft and Camp - SBC     | April 26, 2025 - April 27, 2025 | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Bungee Jump                                    | April 27, 2025                  | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Zion Camp and Explore - SBC                    | May 2, 2025 - May 4, 2025       | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | La Jolla Snorkel and Hike - SBC                | May 4, 2025                     | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Life of Pi @ Ahmanson Theater - SBC            | May 9, 2025                     | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Full Moon Hike - SBC                           | May 11, 2025                    | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Big Sur Camp and Explore - SBC                 | May 18, 2025 - May 21, 2025     | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Getty Villa Museum - SBC                       | May 18, 2025                    | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Sedona Cabin and Explore - SBC and PDC         | May 22, 2025 - May 25, 2025     | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Santa Rosa Island Backpack and Explore - SBC   | May 23, 2025 - May 26, 2025     | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Great Basin National Park and Star Train - SBC | June 5, 2025 - June 8, 2025     | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Huntington Library and Gardens - SBC           | June 5, 2025                    | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | San Francisco Urban Adventure - SBC            | June 12, 2025 - June 15, 2025   | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Aquarium of the Pacific - SBC                  | June 13, 2025                   | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Muir Day Challenge - SBC                       | June 19, 2025 - June 22, 2025   | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | Strawberry Peak Hike - SBC                     | June 22, 2025                   | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | American River Raft and Camp - SBC and PDC     | June 27, 2025 - June 29, 2025   | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+
# | La Jolla Snorkel and Hike - SBC                | June 28, 2025                   | 0 spot(s)    |
# +------------------------------------------------+---------------------------------+--------------+

# %%
from bs4 import BeautifulSoup
import re
import requests
import json
from tabulate import tabulate
from concurrent.futures import ThreadPoolExecutor
import time

# URLs and API endpoints
main_page = "https://www.csusb.edu/recreation-wellness/adventure/trips/all-trips-date"
base_url = "https://www.csusb.edu"
api_url = "https://recshop.csusb.edu/Program/GetOfferingsForSemester"
querystring = {
    "semesterId": "29ff794d-548e-407f-b511-10d04ec2798e",
    "programId": "d921b108-4059-4eef-bd42-9bd9c72c2557"
}
headers = {"cookie": "ASP.NET_SessionId=b4omal1okxattmuwb1rmyqpn"}

def fetch_api_data():
    """Fetch trip data from the RecShop API"""
    try:
        response = requests.get(api_url, params=querystring, headers=headers)
        print(f"API Response Status: {response.status_code}")
        
        if response.status_code == 200:
            # Print a sample of the response to debug
            print(f"API Response Preview: {response.text[:200]}...")
            return json.loads(response.text)
        else:
            print(f"API request failed with status code: {response.status_code}")
            return []
    except Exception as e:
        print(f"Error fetching API data: {e}")
        return []

# Fetch API data and create lookup dictionary
print("Fetching data from API...")
api_data = fetch_api_data()
spots_lookup = {}

if api_data:
    print(f"Successfully retrieved {len(api_data)} items from API")
    for offering in api_data:
        try:
            trip_name = offering.get('Name', '').strip()
            max_registrants = offering.get('MaxRegistrants', 0)
            current_registrations = offering.get('CurrentRegistrations', 0)
            spots_left = max(0, max_registrants - current_registrations)
            
            # Add to lookup with multiple key variations to improve matching
            spots_lookup[trip_name.lower()] = f"{spots_left} spot(s)"
            
            # Create additional keys with simplified text for better matching
            simple_name = re.sub(r'[^\w\s]', '', trip_name).lower()
            spots_lookup[simple_name] = f"{spots_left} spot(s)"
            
            print(f"Added to lookup: {trip_name} -> {spots_left} spots")
        except Exception as e:
            print(f"Error processing API offering: {e}")
else:
    print("No data retrieved from API, will rely on web scraping only")

# Getting the adventure page to get all the current trips
print("Fetching main trips page...")
response = requests.get(main_page)
soup = BeautifulSoup(response.text, 'html.parser')

list_of_href = soup.find_all('a', href=True)
pattern = re.compile(r'\/event\/\d{5,6}')

href_trips = []

for i in list_of_href:
    match = re.search(pattern, str(i))
    if match:
        href_trips.append(match.group())

print(f"Found {len(href_trips)} trips on main page")

def find_fusion_link(trip_soup):
    """Find the link to the fusion page which contains spots left information"""
    # Try different selectors that might contain the fusion link
    fusion_button = trip_soup.find('a', class_="fusion-button")
    if not fusion_button:
        fusion_button = trip_soup.find('p', class_="card-text")
    if not fusion_button:
        fusion_button = trip_soup.find('a', text=re.compile(r'register|sign up', re.IGNORECASE))
    
    if fusion_button and hasattr(fusion_button, 'get') and fusion_button.get('href'):
        return fusion_button.get('href')
    return None

def fetch_trip_info(page):
    """Fetch information for a specific trip page"""
    try:
        trip_url = base_url + page
        print(f"Fetching trip info from: {trip_url}")
        
        trip = requests.get(trip_url)
        trip_soup = BeautifulSoup(trip.text, 'html.parser')
        
        # Extract basic trip information
        trip_date_element = trip_soup.find('div', class_="event--date")
        trip_date = trip_date_element.text.strip() if trip_date_element else "No date found"
        
        trip_name_element = trip_soup.find('h2', class_="event--title")
        trip_name = trip_name_element.text.strip() if trip_name_element else "No title found"
        
        print(f"Found trip: {trip_name} on {trip_date}")
        
        # Try to get spots left information
        spots_left = "N/A"
        
        # First check API data (most reliable)
        trip_key = trip_name.lower()
        simple_key = re.sub(r'[^\w\s]', '', trip_name).lower()
        
        if trip_key in spots_lookup:
            spots_left = spots_lookup[trip_key]
            print(f"Found in API lookup: {spots_left}")
        elif simple_key in spots_lookup:
            spots_left = spots_lookup[simple_key]
            print(f"Found in API lookup (simple match): {spots_left}")
        else:
            # If not in API, try to get the fusion link and check there
            fusion_link = find_fusion_link(trip_soup)
            if fusion_link:
                print(f"Found fusion link: {fusion_link}")
                try:
                    if not fusion_link.startswith('http'):
                        if fusion_link.startswith('/'):
                            fusion_link = base_url + fusion_link
                        else:
                            fusion_link = 'https://' + fusion_link
                    
                    trip_spots = requests.get(fusion_link)
                    fusion_soup = BeautifulSoup(trip_spots.text, 'html.parser')
                    
                    # Try different selectors that might contain spots info
                    spots_element = fusion_soup.find('div', class_="tag-bg-grey spots-tag rounded p-1 mr-3 mb-2")
                    if spots_element and spots_element.find('p', class_="card-text"):
                        spots_left = spots_element.find('p', class_="card-text").text
                        print(f"Found spots from fusion page: {spots_left}")
                    else:
                        # Try alternative selectors
                        spots_text = fusion_soup.find(text=re.compile(r'\d+\s*spot', re.IGNORECASE))
                        if spots_text:
                            spots_left = spots_text
                            print(f"Found spots using regex: {spots_left}")
                except Exception as e:
                    print(f"Error fetching fusion page: {e}")
        
        return [trip_name, trip_date, spots_left]
    except Exception as e:
        print(f"Error processing {page}: {e}")
        return ["Error", "Error", "Error"]

# Using ThreadPoolExecutor to fetch trip info concurrently
print("Starting concurrent fetch of all trips...")
with ThreadPoolExecutor(max_workers=8) as executor:  # Reduced workers to avoid rate limiting
    scraped_data = list(executor.map(fetch_trip_info, href_trips))
    
    # Add small delay between batches to avoid rate limiting
    for i in range(0, len(href_trips), 5):
        batch = href_trips[i:i+5]
        partial_results = list(executor.map(fetch_trip_info, batch))
        scraped_data.extend(partial_results)
        time.sleep(1)  # Small delay between batches

# Filter out error entries
scraped_data = [entry for entry in scraped_data if entry[0] != "Error"]

# Insert header row
scraped_data.insert(0, ["Trip Name", "Trip Date", "Spots left"])

# Print the tabulated data
table = tabulate(scraped_data, headers="firstrow", tablefmt="grid")
print("\n\n--- FINAL RESULTS ---\n")
print(table)

# Save to a file
with open("csusb_trips.txt", "w") as f:
    f.write(table)

print("\nResults saved to csusb_trips.txt")
# Out:
# Fetching data from API...
# API Response Status: 200
# API Response Preview:
#
#     <div class="list-wrapper">
# <input data-val="true" data-val-required="The PromptForFamily field is required." id="PromptForFamily" name="PromptForFamily" type="hidden" value="False" />
# <input...
# Error fetching API data: Expecting value: line 3 column 5 (char 8)
# No data retrieved from API, will rely on web scraping only
# Fetching main trips page...
# Found 33 trips on main page
# Starting concurrent fetch of all trips...
# Fetching trip info from: https://www.csusb.edu/event/577464
# Fetching trip info from: https://www.csusb.edu/event/503544
# Fetching trip info from: https://www.csusb.edu/event/582012
# Fetching trip info from: https://www.csusb.edu/event/99841
# Fetching trip info from: https://www.csusb.edu/event/570378
# Fetching trip info from: https://www.csusb.edu/event/577528
# Fetching trip info from: https://www.csusb.edu/event/100206
# Fetching trip info from: https://www.csusb.edu/event/503542
# Found trip: Black Canyon Canoe and Camp - SBC on April 3, 2025 - April 6, 2025
# Found fusion link: /sites/default/files/upload/file/Who%20Can%20Register%20And%20How%20To%20Do%20It_16.pdf
# Found trip: Silverwood Lake Kayak - SBC on March 9, 2025
# Found fusion link: /sites/default/files/upload/file/2024/Who%20Can%20Register%20And%20How%20To%20Do%20It_1.pdf
# Found trip: Zion Camp and Explore Angels Landing - SBC on March 29, 2025 - April 2, 2025
# Found fusion link: https://www.csusb.edu/sites/default/files/upload/file/Who%20Can%20Register%20And%20How%20To%20Do%20It_21.pdf
# Found trip: Disneyland Shuttle - SBC on March 2, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_93.pdf
# Found trip: Queer Skies Ahead Hike - SBC on March 7, 2025
# Found fusion link: https://recshop.csusb.edu/Program/GetProgramDetails?courseId=15b08a52-fb4f-41f2-9a36-77a642ee2487
# Found trip: Morro Bay Camp and Kayak - SBC on March 14, 2025 - March 16, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_26.pdf
# Found trip: Pinnacles National Park Camp and Explore - SBC on March 21, 2025 - March 23, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_85.pdf
# Found trip: Big Bear Service and Hike - SBC on March 22, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_95.pdf
# /var/folders/sj/rh2rfdw10059tf3j96bb12jh0000gn/T/ipykernel_75006/1210110852.py:87: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   fusion_button = trip_soup.find('a', text=re.compile(r'register|sign up', re.IGNORECASE))
# /var/folders/sj/rh2rfdw10059tf3j96bb12jh0000gn/T/ipykernel_75006/1210110852.py:146: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   spots_text = fusion_soup.find(text=re.compile(r'\d+\s*spot', re.IGNORECASE))
# Fetching trip info from: https://www.csusb.edu/event/577507Fetching trip info from: https://www.csusb.edu/event/500487
#
# Fetching trip info from: https://www.csusb.edu/event/99601
# Fetching trip info from: https://www.csusb.edu/event/500382
# Fetching trip info from: https://www.csusb.edu/event/577531
# Fetching trip info from: https://www.csusb.edu/event/585714
# Fetching trip info from: https://www.csusb.edu/event/577534
# Fetching trip info from: https://www.csusb.edu/event/99596
# Found trip: Six Flags Magic Mountain - SBC on April 6, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_100.pdf
# Found trip: Leo Carrillo Beach Camp and Explore - SBC on April 12, 2025 - April 13, 2025
# Found fusion link: https://recshop.csusb.edu/Program/GetProgramDetails?courseId=54d62972-c7bb-4097-9675-302d6a501d9c
# Found trip: La Jolla Snorkel and Hike - SBC on April 13, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_57.pdf
# Found trip: Yosemite Camp and Explore - SBC on April 18, 2025 - April 20, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_22.pdf
# Found trip: Tahquitz Peak Hike - SBC on April 19, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_99.pdf
# Found trip: SAIL Program Only: Silverwood Lake Kayak - SBC on April 25, 2025
# Found fusion link: https://recshop.csusb.edu/Program/GetProgramDetails?courseId=915640bd-e013-44a3-a722-3e6ede89d3ec
# Found trip: Indoor Skydiving - SBC on April 25, 2025
# Found fusion link: https://recshop.csusb.edu/Program/GetProgramDetails?courseId=2987bdf9-6aaa-4ec8-8345-8be80503d003
# Found trip: Kings River Whitewater Raft and Camp - SBC on April 26, 2025 - April 27, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_25.pdf
# Fetching trip info from: https://www.csusb.edu/event/97266
# Fetching trip info from: https://www.csusb.edu/event/500551
# Fetching trip info from: https://www.csusb.edu/event/578552
# Fetching trip info from: https://www.csusb.edu/event/578551
# Fetching trip info from: https://www.csusb.edu/event/578547
# Fetching trip info from: https://www.csusb.edu/event/503540Fetching trip info from: https://www.csusb.edu/event/501271
#
# Fetching trip info from: https://www.csusb.edu/event/552629
# Found trip: Life of Pi @ Ahmanson Theater - SBC on May 9, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_101.pdf
# Found trip: La Jolla Snorkel and Hike - SBC on May 4, 2025
# Found fusion link: /sites/default/files/upload/file/2024/Who%20Can%20Register%20And%20How%20To%20Do%20It_4.pdf
# Found trip: Zion Camp and Explore - SBC on May 2, 2025 - May 4, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_18.pdf
# Found trip: Bungee Jump on April 27, 2025
# Found fusion link: https://www.csusb.edu/sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_21.pdf
# Found trip: Full Moon Hike - SBC on May 11, 2025
# Found fusion link: /sites/default/files/upload/file/2024/Who%20Can%20Register%20And%20How%20To%20Do%20It_15.pdf
# Found trip: Getty Villa Museum - SBC on May 18, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_21.pdf
# Found trip: Big Sur Camp and Explore - SBC on May 18, 2025 - May 21, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_0.pdf
# Found trip: Sedona Cabin and Explore - SBC and PDC on May 22, 2025 - May 25, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_58.pdf
# Fetching trip info from: https://www.csusb.edu/event/500481
# Fetching trip info from: https://www.csusb.edu/event/580197
# Fetching trip info from: https://www.csusb.edu/event/500557
# Fetching trip info from: https://www.csusb.edu/event/534830
# Fetching trip info from: https://www.csusb.edu/event/582076
# Fetching trip info from: https://www.csusb.edu/event/99301
# Found trip: Huntington Library and Gardens - SBC on June 5, 2025
# Found fusion link: https://www.csusb.edu/sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_21.pdf
# Found trip: Great Basin National Park and Star Train - SBC on June 5, 2025 - June 8, 2025
# Found fusion link: /sites/default/files/upload/file/%5Bdate%3Acustom%3AY%5D/Who%20Can%20Register%20And%20How%20To%20Do%20It_0.pdf
# Found trip: Santa Rosa Island Backpack and Explore - SBC on May 23, 2025 - May 26, 2025
# Found fusion link: http://https://www.csusb.edu/recreation-wellness/outdoor-adventures#register
# Fetching trip info from: https://www.csusb.edu/event/585600
# Fetching trip info from: https://www.csusb.edu/event/500009
# Found trip: Aquarium of the Pacific - SBC on June 13, 2025
# Fetching trip info from: https://www.csusb.edu/event/553312
# Found trip: San Francisco Urban Adventure - SBC on June 12, 2025 - June 15, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_63.pdf
# Error fetching fusion page: HTTPConnectionPool(host='https', port=80): Max retries exceeded with url: /www.csusb.edu/recreation-wellness/outdoor-adventures (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x12562be00>: Failed to resolve 'https' ([Errno 8] nodename nor servname provided, or not known)"))
# Found trip: Muir Day Challenge - SBC on June 19, 2025 - June 22, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_30.pdf
# Found trip: Strawberry Peak Hike - SBC on June 22, 2025
# Found trip: La Jolla Snorkel and Hike - SBC on June 28, 2025
# Found trip: American River Raft and Camp - SBC and PDC on June 27, 2025 - June 29, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_31.pdf
# Fetching trip info from: https://www.csusb.edu/event/577464Fetching trip info from: https://www.csusb.edu/event/503544
# Fetching trip info from: https://www.csusb.edu/event/582012
#
# Fetching trip info from: https://www.csusb.edu/event/99841
# Fetching trip info from: https://www.csusb.edu/event/570378
# Found trip: Disneyland Shuttle - SBC on March 2, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_93.pdf
# Found trip: Morro Bay Camp and Kayak - SBC on March 14, 2025 - March 16, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_26.pdf
# Found trip: Silverwood Lake Kayak - SBC on March 9, 2025
# Found fusion link: /sites/default/files/upload/file/2024/Who%20Can%20Register%20And%20How%20To%20Do%20It_1.pdf
# Found trip: Pinnacles National Park Camp and Explore - SBC on March 21, 2025 - March 23, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_85.pdf
# Found trip: Queer Skies Ahead Hike - SBC on March 7, 2025
# Found fusion link: https://recshop.csusb.edu/Program/GetProgramDetails?courseId=15b08a52-fb4f-41f2-9a36-77a642ee2487
# Fetching trip info from: https://www.csusb.edu/event/577528Fetching trip info from: https://www.csusb.edu/event/100206
# Fetching trip info from: https://www.csusb.edu/event/503542
#
# Fetching trip info from: https://www.csusb.edu/event/577507
# Fetching trip info from: https://www.csusb.edu/event/500487
# Found trip: Leo Carrillo Beach Camp and Explore - SBC on April 12, 2025 - April 13, 2025
# Found fusion link: https://recshop.csusb.edu/Program/GetProgramDetails?courseId=54d62972-c7bb-4097-9675-302d6a501d9c
# Found trip: Six Flags Magic Mountain - SBC on April 6, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_100.pdf
# Found trip: Black Canyon Canoe and Camp - SBC on April 3, 2025 - April 6, 2025
# Found fusion link: /sites/default/files/upload/file/Who%20Can%20Register%20And%20How%20To%20Do%20It_16.pdf
# Found trip: Big Bear Service and Hike - SBC on March 22, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_95.pdf
# Found trip: Zion Camp and Explore Angels Landing - SBC on March 29, 2025 - April 2, 2025
# Found fusion link: https://www.csusb.edu/sites/default/files/upload/file/Who%20Can%20Register%20And%20How%20To%20Do%20It_21.pdf
# Fetching trip info from: https://www.csusb.edu/event/99601
# Fetching trip info from: https://www.csusb.edu/event/500382
# Fetching trip info from: https://www.csusb.edu/event/577531
# Fetching trip info from: https://www.csusb.edu/event/585714
# Fetching trip info from: https://www.csusb.edu/event/577534
# Found trip: La Jolla Snorkel and Hike - SBC on April 13, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_57.pdf
# Found trip: SAIL Program Only: Silverwood Lake Kayak - SBC on April 25, 2025
# Found trip: Tahquitz Peak Hike - SBC on April 19, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_99.pdf
# Found fusion link: https://recshop.csusb.edu/Program/GetProgramDetails?courseId=915640bd-e013-44a3-a722-3e6ede89d3ec
# Found trip: Indoor Skydiving - SBC on April 25, 2025
# Found fusion link: https://recshop.csusb.edu/Program/GetProgramDetails?courseId=2987bdf9-6aaa-4ec8-8345-8be80503d003
# Found trip: Yosemite Camp and Explore - SBC on April 18, 2025 - April 20, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_22.pdf
# Fetching trip info from: https://www.csusb.edu/event/99596Fetching trip info from: https://www.csusb.edu/event/97266
#
# Fetching trip info from: https://www.csusb.edu/event/500551
# Fetching trip info from: https://www.csusb.edu/event/578552
# Fetching trip info from: https://www.csusb.edu/event/578551
# Found trip: Life of Pi @ Ahmanson Theater - SBC on May 9, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_101.pdf
# Found trip: Kings River Whitewater Raft and Camp - SBC on April 26, 2025 - April 27, 2025
# Found trip: Bungee Jump on April 27, 2025
# Found fusion link: https://www.csusb.edu/sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_21.pdf
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_25.pdf
# Found trip: Zion Camp and Explore - SBC on May 2, 2025 - May 4, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_18.pdf
# Found trip: La Jolla Snorkel and Hike - SBC on May 4, 2025
# Found fusion link: /sites/default/files/upload/file/2024/Who%20Can%20Register%20And%20How%20To%20Do%20It_4.pdf
# Fetching trip info from: https://www.csusb.edu/event/578547Fetching trip info from: https://www.csusb.edu/event/503540
# Fetching trip info from: https://www.csusb.edu/event/501271
#
# Fetching trip info from: https://www.csusb.edu/event/552629
# Fetching trip info from: https://www.csusb.edu/event/500481
# Found trip: Full Moon Hike - SBC on May 11, 2025
# Found trip: Getty Villa Museum - SBC on May 18, 2025
# Found trip: Big Sur Camp and Explore - SBC on May 18, 2025 - May 21, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_0.pdf
# Found trip: Sedona Cabin and Explore - SBC and PDC on May 22, 2025 - May 25, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_58.pdf
# Found trip: Santa Rosa Island Backpack and Explore - SBC on May 23, 2025 - May 26, 2025
# Found fusion link: http://https://www.csusb.edu/recreation-wellness/outdoor-adventures#register
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_21.pdf
# Found fusion link: /sites/default/files/upload/file/2024/Who%20Can%20Register%20And%20How%20To%20Do%20It_15.pdf
# Error fetching fusion page: HTTPConnectionPool(host='https', port=80): Max retries exceeded with url: /www.csusb.edu/recreation-wellness/outdoor-adventures (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x1252f1f10>: Failed to resolve 'https' ([Errno 8] nodename nor servname provided, or not known)"))
# Fetching trip info from: https://www.csusb.edu/event/580197Fetching trip info from: https://www.csusb.edu/event/500557
# Fetching trip info from: https://www.csusb.edu/event/534830
#
# Fetching trip info from: https://www.csusb.edu/event/582076
# Fetching trip info from: https://www.csusb.edu/event/99301
# Found trip: Huntington Library and Gardens - SBC on June 5, 2025
# Found fusion link: https://www.csusb.edu/sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_21.pdf
# Found trip: San Francisco Urban Adventure - SBC on June 12, 2025 - June 15, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_63.pdf
# Found trip: Great Basin National Park and Star Train - SBC on June 5, 2025 - June 8, 2025
# Found fusion link: /sites/default/files/upload/file/%5Bdate%3Acustom%3AY%5D/Who%20Can%20Register%20And%20How%20To%20Do%20It_0.pdf
# Found trip: Aquarium of the Pacific - SBC on June 13, 2025
# Found trip: Muir Day Challenge - SBC on June 19, 2025 - June 22, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_30.pdf
# Fetching trip info from: https://www.csusb.edu/event/585600Fetching trip info from: https://www.csusb.edu/event/500009
# Fetching trip info from: https://www.csusb.edu/event/553312
#
# Found trip: Strawberry Peak Hike - SBC on June 22, 2025
# Found trip: La Jolla Snorkel and Hike - SBC on June 28, 2025
# Found trip: American River Raft and Camp - SBC and PDC on June 27, 2025 - June 29, 2025
# Found fusion link: /sites/default/files/Who%20Can%20Register%20And%20How%20To%20Do%20It_31.pdf
#
#
# --- FINAL RESULTS ---
#
# +------------------------------------------------+---------------------------------+--------------+
# | Trip Name                                      | Trip Date                       | Spots left   |
# +================================================+=================================+==============+
# | Disneyland Shuttle - SBC                       | March 2, 2025                   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Queer Skies Ahead Hike - SBC                   | March 7, 2025                   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Silverwood Lake Kayak - SBC                    | March 9, 2025                   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Morro Bay Camp and Kayak - SBC                 | March 14, 2025 - March 16, 2025 | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Pinnacles National Park Camp and Explore - SBC | March 21, 2025 - March 23, 2025 | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Big Bear Service and Hike - SBC                | March 22, 2025                  | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Zion Camp and Explore Angels Landing - SBC     | March 29, 2025 - April 2, 2025  | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Black Canyon Canoe and Camp - SBC              | April 3, 2025 - April 6, 2025   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Six Flags Magic Mountain - SBC                 | April 6, 2025                   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Leo Carrillo Beach Camp and Explore - SBC      | April 12, 2025 - April 13, 2025 | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | La Jolla Snorkel and Hike - SBC                | April 13, 2025                  | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Yosemite Camp and Explore - SBC                | April 18, 2025 - April 20, 2025 | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Tahquitz Peak Hike - SBC                       | April 19, 2025                  | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | SAIL Program Only: Silverwood Lake Kayak - SBC | April 25, 2025                  | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Indoor Skydiving - SBC                         | April 25, 2025                  | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Kings River Whitewater Raft and Camp - SBC     | April 26, 2025 - April 27, 2025 | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Bungee Jump                                    | April 27, 2025                  | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Zion Camp and Explore - SBC                    | May 2, 2025 - May 4, 2025       | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | La Jolla Snorkel and Hike - SBC                | May 4, 2025                     | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Life of Pi @ Ahmanson Theater - SBC            | May 9, 2025                     | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Full Moon Hike - SBC                           | May 11, 2025                    | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Big Sur Camp and Explore - SBC                 | May 18, 2025 - May 21, 2025     | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Getty Villa Museum - SBC                       | May 18, 2025                    | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Sedona Cabin and Explore - SBC and PDC         | May 22, 2025 - May 25, 2025     | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Santa Rosa Island Backpack and Explore - SBC   | May 23, 2025 - May 26, 2025     | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Great Basin National Park and Star Train - SBC | June 5, 2025 - June 8, 2025     | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Huntington Library and Gardens - SBC           | June 5, 2025                    | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | San Francisco Urban Adventure - SBC            | June 12, 2025 - June 15, 2025   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Aquarium of the Pacific - SBC                  | June 13, 2025                   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Muir Day Challenge - SBC                       | June 19, 2025 - June 22, 2025   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Strawberry Peak Hike - SBC                     | June 22, 2025                   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | American River Raft and Camp - SBC and PDC     | June 27, 2025 - June 29, 2025   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | La Jolla Snorkel and Hike - SBC                | June 28, 2025                   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Disneyland Shuttle - SBC                       | March 2, 2025                   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Queer Skies Ahead Hike - SBC                   | March 7, 2025                   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Silverwood Lake Kayak - SBC                    | March 9, 2025                   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Morro Bay Camp and Kayak - SBC                 | March 14, 2025 - March 16, 2025 | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Pinnacles National Park Camp and Explore - SBC | March 21, 2025 - March 23, 2025 | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Big Bear Service and Hike - SBC                | March 22, 2025                  | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Zion Camp and Explore Angels Landing - SBC     | March 29, 2025 - April 2, 2025  | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Black Canyon Canoe and Camp - SBC              | April 3, 2025 - April 6, 2025   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Six Flags Magic Mountain - SBC                 | April 6, 2025                   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Leo Carrillo Beach Camp and Explore - SBC      | April 12, 2025 - April 13, 2025 | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | La Jolla Snorkel and Hike - SBC                | April 13, 2025                  | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Yosemite Camp and Explore - SBC                | April 18, 2025 - April 20, 2025 | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Tahquitz Peak Hike - SBC                       | April 19, 2025                  | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | SAIL Program Only: Silverwood Lake Kayak - SBC | April 25, 2025                  | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Indoor Skydiving - SBC                         | April 25, 2025                  | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Kings River Whitewater Raft and Camp - SBC     | April 26, 2025 - April 27, 2025 | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Bungee Jump                                    | April 27, 2025                  | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Zion Camp and Explore - SBC                    | May 2, 2025 - May 4, 2025       | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | La Jolla Snorkel and Hike - SBC                | May 4, 2025                     | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Life of Pi @ Ahmanson Theater - SBC            | May 9, 2025                     | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Full Moon Hike - SBC                           | May 11, 2025                    | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Big Sur Camp and Explore - SBC                 | May 18, 2025 - May 21, 2025     | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Getty Villa Museum - SBC                       | May 18, 2025                    | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Sedona Cabin and Explore - SBC and PDC         | May 22, 2025 - May 25, 2025     | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Santa Rosa Island Backpack and Explore - SBC   | May 23, 2025 - May 26, 2025     | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Great Basin National Park and Star Train - SBC | June 5, 2025 - June 8, 2025     | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Huntington Library and Gardens - SBC           | June 5, 2025                    | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | San Francisco Urban Adventure - SBC            | June 12, 2025 - June 15, 2025   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Aquarium of the Pacific - SBC                  | June 13, 2025                   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Muir Day Challenge - SBC                       | June 19, 2025 - June 22, 2025   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | Strawberry Peak Hike - SBC                     | June 22, 2025                   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | American River Raft and Camp - SBC and PDC     | June 27, 2025 - June 29, 2025   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
# | La Jolla Snorkel and Hike - SBC                | June 28, 2025                   | N/A          |
# +------------------------------------------------+---------------------------------+--------------+
#
# Results saved to csusb_trips.txt
