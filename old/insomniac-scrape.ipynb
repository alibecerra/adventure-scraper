# %%
import http.client

conn = http.client.HTTPSConnection("recshop.csusb.edu")

payload = ""

headers = { 'cookie': "ASP.NET_SessionId=b4omal1okxattmuwb1rmyqpn" }

conn.request("GET", "/Program/GetOfferingsForSemester?semesterId=29ff794d-548e-407f-b511-10d04ec2798e&programId=d921b108-4059-4eef-bd42-9bd9c72c2557", payload, headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
#     <div class="list-wrapper">
# <input data-val="true" data-val-required="The PromptForFamily field is required." id="PromptForFamily" name="PromptForFamily" type="hidden" value="False" />
# <input data-val="true" data-val-required="The IsSuspendedFromPrograms field is required." id="IsSuspended" name="IsSuspendedFromPrograms" type="hidden" value="False" />
#
#
#
# <div class="offering-card col-12" data-offering-id="dc283260-7bdc-4ba8-83ed-66257d464b40">
#     <div class="accordion d-block">
#         <div class="card mb-3">
#             <div class="card-header bg-transparent" id="headingOne-1">
#                 <div class="d-md-flex flex-md-row flex-column">
#                     <div class="collapse-btn pr-3 d-none d-md-block">
#                         <button class="border-0 bg-transparent" data-toggle="collapse" data-target="#offering-collapse-1" aria-expanded="false" aria-controls="offering-collapse-1">
# ...

# %%
def insomniac(semester_id, program_id):
    conn = http.client.HTTPSConnection("recshop.csusb.edu")

    payload = ""

    headers = { 'cookie': "ASP.NET_SessionId=b4omal1okxattmuwb1rmyqpn" }

    conn.request("GET", f"/Program/GetOfferingsForSemester?semesterId={semester_id}&programId={program_id}", payload, headers)

    res = conn.getresponse()
    data = res.read()

    print(data.decode("utf-8"))
    # https://recshop.csusb.edu/Program/GetProgramDetails?courseId=3d29aed3-87b5-474d-a007-9138f522c964
